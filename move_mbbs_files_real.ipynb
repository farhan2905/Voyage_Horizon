# %% [markdown]
# # Move MBBS Location Pages
# This notebook moves the newly created MBBS location HTML files into the `mbbs_abroad/` directory and verifies the move.

# %%
import os
import shutil

workspace_root = os.path.abspath('.')
source_dir = workspace_root
mbbs_abroad_dir = os.path.join(source_dir, 'mbbs_abroad')

print('Workspace root:', workspace_root)
print('Source directory:', source_dir)
print('Target mbbs_abroad directory:', mbbs_abroad_dir)
# Out:
# Workspace root: /workspaces/codespaces-blank/Voyage_Horizon
# Source directory: /workspaces/codespaces-blank/Voyage_Horizon
# Target mbbs_abroad directory: /workspaces/codespaces-blank/Voyage_Horizon/mbbs_abroad

# %%
os.makedirs(mbbs_abroad_dir, exist_ok=True)
print('Ensured directory exists:', mbbs_abroad_dir)
# Out:
# Ensured directory exists: /workspaces/codespaces-blank/Voyage_Horizon/mbbs_abroad

# %%
files_to_move = [
    'georgia.html',
    'russia.html',
    'kyrgyzstan.html',
    'kazakhstan.html',
    'uzbekistan.html',
    'egypt.html',
    'vietnam.html',
    'iraq.html',
    'nepal.html',
    'italy.html'
]

print('Files to move:')
for file in files_to_move:
    print('-', file)
# Out:
# Files to move:
# - georgia.html
# - russia.html
# - kyrgyzstan.html
# - kazakhstan.html
# - uzbekistan.html
# - egypt.html
# - vietnam.html
# - iraq.html
# - nepal.html
# - italy.html

# %%
moved_files = []
failed_files = []

for filename in files_to_move:
    src = os.path.join(source_dir, filename)
    dst = os.path.join(mbbs_abroad_dir, filename)
    try:
        shutil.move(src, dst)
        moved_files.append(filename)
    except Exception as exc:
        failed_files.append((filename, str(exc)))

print('Moved files:', moved_files)
if failed_files:
    print('Failed files:')
    for filename, error in failed_files:
        print('-', filename, error)
# Out:
# Moved files: []
# Failed files:
# - georgia.html [Errno 2] No such file or directory: '/workspaces/codespaces-blank/Voyage_Horizon/georgia.html'
# - russia.html [Errno 2] No such file or directory: '/workspaces/codespaces-blank/Voyage_Horizon/russia.html'
# - kyrgyzstan.html [Errno 2] No such file or directory: '/workspaces/codespaces-blank/Voyage_Horizon/kyrgyzstan.html'
# - kazakhstan.html [Errno 2] No such file or directory: '/workspaces/codespaces-blank/Voyage_Horizon/kazakhstan.html'
# - uzbekistan.html [Errno 2] No such file or directory: '/workspaces/codespaces-blank/Voyage_Horizon/uzbekistan.html'
# - egypt.html [Errno 2] No such file or directory: '/workspaces/codespaces-blank/Voyage_Horizon/egypt.html'
# - vietnam.html [Errno 2] No such file or directory: '/workspaces/codespaces-blank/Voyage_Horizon/vietnam.html'
# - iraq.html [Errno 2] No such file or directory: '/workspaces/codespaces-blank/Voyage_Horizon/iraq.html'
# - nepal.html [Errno 2] No such file or directory: '/workspaces/codespaces-blank/Voyage_Horizon/nepal.html'
# - italy.html [Errno 2] No such file or directory: '/workspaces/codespaces-blank/Voyage_Horizon/italy.html'

# %%
print('Contents of mbbs_abroad after move:')
for entry in sorted(os.listdir(mbbs_abroad_dir)):
    print('-', entry)

print('')
print('Root directory check:')
for filename in files_to_move:
    print(filename, 'exists in root?', os.path.exists(os.path.join(source_dir, filename)))
# Out:
# Contents of mbbs_abroad after move:
# - egypt.html
# - georgia.html
# - iraq.html
# - italy.html
# - kazakhstan.html
# - kyrgyzstan.html
# - nepal.html
# - russia.html
# - uzbekistan.html
# - vietnam.html
#
# Root directory check:
# georgia.html exists in root? False
# russia.html exists in root? False
# kyrgyzstan.html exists in root? False
# kazakhstan.html exists in root? False
# uzbekistan.html exists in root? False
# egypt.html exists in root? False
# vietnam.html exists in root? False
# iraq.html exists in root? False
# nepal.html exists in root? False
# italy.html exists in root? False
